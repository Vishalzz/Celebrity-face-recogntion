# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h3 style='color:green'>(1) Preprocessing/testing: Detect face and eyes</h3>

# %%
img = cv2.imread('./test_images/2Q__ (2).jpg')
img.shape
# Out:
# (100, 100, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (100, 100)

# %%
gray
# Out:
# array([[43, 43, 44, ..., 30, 30, 30],
#        [44, 44, 45, ..., 31, 31, 31],
#        [45, 45, 46, ..., 33, 33, 33],
#        ...,
#        [55, 53, 46, ..., 16, 20, 22],
#        [55, 54, 47, ..., 13, 17, 19],
#        [55, 54, 48, ..., 12, 16, 18]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[19, 16, 52, 52]], dtype=int32)

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (19, 16, 52, 52)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %% [markdown]
# <h3 style='color:green'>(2) Preprocessing: Crop the facial region of the image</h3>

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (52, 52, 3)

# %% [markdown]
# <h3 style='color:green'>(3) Preprocessing: Use wavelet transform as a feature for traning our model</h3>

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/images.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/images.jpg')
plt.imshow(cropped_image)

# %%
org_image_obstructed = cv2.imread('./test_images/download.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/download.jpg')
(cropped_image_no_2_eyes)

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/arya stark',
#  './dataset/cersei lannister',
#  './dataset/daenerys targaryen',
#  './dataset/jon snow',
#  './dataset/tyrion lannister']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/arya stark
# Generating cropped images in folder:  ./dataset/cropped/cersei lannister
# Generating cropped images in folder:  ./dataset/cropped/daenerys targaryen
# Generating cropped images in folder:  ./dataset/cropped/jon snow
# Generating cropped images in folder:  ./dataset/cropped/tyrion lannister

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'arya stark': ['./dataset/cropped/arya stark\\arya stark1.png',
#   './dataset/cropped/arya stark\\arya stark10.png',
#   './dataset/cropped/arya stark\\arya stark11.png',
#   './dataset/cropped/arya stark\\arya stark12.png',
#   './dataset/cropped/arya stark\\arya stark13.png',
#   './dataset/cropped/arya stark\\arya stark14.png',
#   './dataset/cropped/arya stark\\arya stark2.png',
#   './dataset/cropped/arya stark\\arya stark3.png',
#   './dataset/cropped/arya stark\\arya stark4.png',
#   './dataset/cropped/arya stark\\arya stark5.png',
#   './dataset/cropped/arya stark\\arya stark6.png',
#   './dataset/cropped/arya stark\\arya stark7.png',
#   './dataset/cropped/arya stark\\arya stark8.png',
#   './dataset/cropped/arya stark\\arya stark9.png'],
#  'cersei lannister': ['./dataset/cropped/cersei lannister\\cersei lannister1.png',
#   './dataset/cropped/cersei lannister\\cersei lannister10.png',
#   './dataset/cropped/cersei lannister\\cersei lannister11.png',
#   './dataset/cropped/cersei lannister\\cersei lannister12.png',
#   './dataset/cropped/cersei lannister\\cersei lannister13.png',
#   './dataset/cropped/cersei lannister\\cersei lannister14.png',
#   './dataset/cropped/cersei lannister\\cersei lannister2.png',
#   './dataset/cropped/cersei lannister\\cersei lannister3.png',
#   './dataset/cropped/cersei lannister\\cersei lannister4.png',
#   './dataset/cropped/cersei lannister\\cersei lannister5.png',
#   './dataset/cropped/cersei lannister\\cersei lannister6.png',
#   './dataset/cropped/cersei lannister\\cersei lannister7.png',
#   './dataset/cropped/cersei lannister\\cersei lannister8.png',
#   './dataset/cropped/cersei lannister\\cersei lannister9.png'],
#  'daenerys targaryen': ['./dataset/cropped/daenerys targaryen\\daenerys targaryen1.png',
#   './dataset/cropped/daenerys targaryen\\daenerys targaryen10.png',
#   './dataset/cropped/daenerys targaryen\\daenerys targaryen11.png',
#   './dataset/cropped/daenerys targaryen\\daenerys targaryen12.png',
#   './dataset/cropped/daenerys targaryen\\daenerys targaryen13.png',
#   './dataset/cropped/daenerys targaryen\\daenerys targaryen14.png',
#   './dataset/cropped/daenerys targaryen\\daenerys targaryen15.png',
#   './dataset/cropped/daenerys targaryen\\daenerys targaryen16.png',
#   './dataset/cropped/daenerys targaryen\\daenerys targaryen17.png',
#   './dataset/cropped/daenerys targaryen\\daenerys targaryen18.png',
#   './dataset/cropped/daenerys targaryen\\daenerys targaryen19.png',
#   './dataset/cropped/daenerys targaryen\\daenerys targaryen2.png',
#   './dataset/cropped/daenerys targaryen\\daenerys targaryen20.png',
#   './dataset/cropped/daenerys targaryen\\daenerys targaryen21.png',
#   './dataset/cropped/daenerys targaryen\\daenerys targaryen22.png',
#   './dataset/cropped/daenerys targaryen\\daenerys targaryen3.png',
#   './dataset/cropped/daenerys targaryen\\daenerys targaryen4.png',
#   './dataset/cropped/daenerys targaryen\\daenerys targaryen5.png',
#   './dataset/cropped/daenerys targaryen\\daenerys targaryen6.png',
#   './dataset/cropped/daenerys targaryen\\daenerys targaryen7.png',
#   './dataset/cropped/daenerys targaryen\\daenerys targaryen8.png',
#   './dataset/cropped/daenerys targaryen\\daenerys targaryen9.png'],
#  'jon snow': ['./dataset/cropped/jon snow\\jon snow1.png',
#   './dataset/cropped/jon snow\\jon snow2.png',
#   './dataset/cropped/jon snow\\jon snow3.png',
#   './dataset/cropped/jon snow\\jon snow4.png',
#   './dataset/cropped/jon snow\\jon snow5.png'],
#  'tyrion lannister': ['./dataset/cropped/tyrion lannister\\tyrion lannister1.png',
#   './dataset/cropped/tyrion lannister\\tyrion lannister2.png',
#   './dataset/cropped/tyrion lannister\\tyrion lannister3.png',
#   './dataset/cropped/tyrion lannister\\tyrion lannister4.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'arya stark': 0,
#  'cersei lannister': 1,
#  'daenerys targaryen': 2,
#  'jon snow': 3,
#  'tyrion lannister': 4}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
X[0]
# Out:
# array([[122],
#        [133],
#        [145],
#        ...,
#        [  4],
#        [  6],
#        [ 23]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (59, 4096)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.7333333333333333

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75         4
#            1       0.33      0.50      0.40         2
#            2       0.88      0.78      0.82         9
#
#     accuracy                           0.73        15
#    macro avg       0.65      0.68      0.66        15
# weighted avg       0.77      0.73      0.75        15

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
# C:\Users\visha\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# C:\Users\visha\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# C:\Users\visha\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
#                  model  best_score  \
# 0                  svm    0.636111
# 1        random_forest    0.480556
# 2  logistic_regression    0.541667
#
#                                    best_params
# 0          {'svc__C': 1, 'svc__kernel': 'rbf'}
# 1  {'randomforestclassifier__n_estimators': 5}
# 2                 {'logisticregression__C': 1}
